# %%
# !ls /kaggle/input
# !pip install -r  /kaggle/input/signate251code/main/requirements.txt
# Out:
# petbottle-label  signate251code
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 80.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 61.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 29.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00
# ...

# %%
# !python /kaggle/input/signate251code/main/prepare_dataset.py \
    --src /kaggle/input/petbottle-label \
    --dst /kaggle/working/dataset/ \
    --force
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Annotations /kaggle/input/petbottle-label/annotations/train.json: 100%|█████████
# COCO data converted successfully.
# Results saved to /kaggle/working/dataset
# 100%|████████████████████████████████████| 11011/11011 [00:25<00:00, 426.70it/s]
# [{'id': 1, 'name': 'object'}]

# %%
# !python /kaggle/input/signate251code/main/train.py \
#     -c /kaggle/working/dataset/data.yaml \
#     -o /kaggle/working/output \
#     -m yolo11m

# %%
# !python /kaggle/input/signate251code/main/convnextNote.py
# Out:
#    id file_name  height  width
# 0   1    T1.jpg    1080   1793
# 1   2    T2.jpg    1080   1559
# 2   3    T3.jpg    1080   1620
# 3   4    T4.jpg    1080   1745
# 4   5    T5.jpg     719   1920
#    id  image_id  category_id                   bbox
# 0   1         1           43   [532, 367, 199, 497]
# 1   2         1           42  [1094, 457, 179, 420]
# 2   3         2           57    [73, 309, 292, 666]
# 3   4         2           58   [747, 518, 273, 503]
# 4   5         3           32   [513, 499, 124, 253]
#    id supercategory                      name
# 0   1           can  light_sugar_coffe1_185ml
# 1   2           can        sweet_coffe1_180ml
# 2   3           can        sweet_coffe2_250ml
# 3   4           can  light_sugar_coffe4_150ml
# 4   5           can        sweet_coffe3_185ml
#     category_id              category_name  count
# 0            49        orange_juice1_160ml    381
# 1            47    grapefruit_juice1_400ml    354
# ...

# %%
# import os
# from PIL import Image
# from IPython.display import display

# # 画像フォルダのパス
# folder_path = '/kaggle/working'

# # フォルダ内のファイル名一覧を取得
# files = os.listdir(folder_path)

# # 画像ファイルだけ表示（拡張子で判別）
# for file in files:
#     if file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
#         img_path = os.path.join(folder_path, file)
#         img = Image.open(img_path)
#         display(img)

# %%
# !python /kaggle/input/signate251code/submit/src/predict_pth.py \
# /kaggle/input/signate251code/submit/model/convnextv2_base.fcmae_ft_in22k_in1k.pth \
# /kaggle/input/signate251code/images --batch-size 32
